# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv("../data/tests_5v.csv")

# %%
df.head()
# Out:
#   cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 0    AT  ESS1-8e01       1.0  12.12.2018       1  ESS1e06_6         1
# 1    AT  ESS1-8e01       1.0  12.12.2018       2  ESS1e06_6         1
# 2    AT  ESS1-8e01       1.0  12.12.2018       3  ESS1e06_6         1
# 3    AT  ESS1-8e01       1.0  12.12.2018       4  ESS1e06_6         1
# 4    AT  ESS1-8e01       1.0  12.12.2018       5  ESS1e06_6         1
#
#    edition  idno  dweight   pspwght   pweight  happy  sclmeet  inmdisc  \
# 0      6.6     1   0.9452  0.940933  0.271488      8        5      1.0
# 1      6.6     2   0.4726  0.470466  0.271488      4        6      2.0
# 2      6.6     3   0.9452  1.392155  0.271488      7        5      1.0
# 3      6.6     4   0.9452  1.382163  0.271488      9        5      1.0
# 4      6.6     6   1.8905  1.437766  0.271488      9        5      1.0
#
#    inprdsc  aesfdrk  rlgdnat  rlgdnbat  rlgdnbe  rlgdnch  rlgdnach  rlgdncy  \
# ...

# %%
df.columns
# Out:
# Index(['cntry', 'cname', 'cedition', 'cproddat', 'cseqno', 'name', 'essround',
#        'edition', 'idno', 'dweight', 'pspwght', 'pweight', 'happy', 'sclmeet',
#        'inmdisc', 'inprdsc', 'aesfdrk', 'rlgdnat', 'rlgdnbat', 'rlgdnbe',
#        'rlgdnch', 'rlgdnach', 'rlgdncy', 'rlgdnde', 'rlgdnade', 'rlgdnfi',
#        'rlgdnafi', 'rlgdngb', 'rlgdngr', 'rlgdnagr', 'rlgdnhu', 'rlgdnie',
#        'rlgdnil', 'rlgdnis', 'rlgdnlt', 'rlgdnnl', 'rlgdnno', 'rlgdnpl',
#        'rlgdnapl', 'rlgdnpt', 'rlgdnru', 'rlgdnaru', 'rlgdnse', 'rlgdnase',
#        'rlgdnsi', 'rlgdnsk', 'rlgdnua', 'rlgdeat', 'rlgdebat', 'rlgdebe',
#        'rlgdech', 'rlgdeach', 'rlgdecy', 'rlgdede', 'rlgdeade', 'rlgdefi',
#        'rlgdeafi', 'rlgdegb', 'rlgdegr', 'rlgdeagr', 'rlgdehu', 'rlgdeie',
#        'rlgdeil', 'rlgdeis', 'rlgdelt', 'rlgdenl', 'rlgdeno', 'rlgdepl',
#        'rlgdeapl', 'rlgdept', 'rlgderu', 'rlgdearu', 'rlgdese', 'rlgdease',
#        'rlgdesi', 'rlgdesk', 'rlgdeua'],
#       dtype='object')

# %%
df2 = df[['cntry','essround','idno','happy', 'sclmeet']]

# %%
df2.shape
# Out:
# (374729, 6)

# %%
cols = {"cntry":"country",
        "happy":"happy",
        "sclmeet":"social_often"}

# %%
df3 = df2.rename(columns=cols)

# %%
df3["essround"].value_counts()
# Out:
# 4    52626
# 5    52458
# 6    52177
# 2    47537
# 8    44387
# 3    43000
# 1    42359
# 7    40185
# Name: essround, dtype: int64
