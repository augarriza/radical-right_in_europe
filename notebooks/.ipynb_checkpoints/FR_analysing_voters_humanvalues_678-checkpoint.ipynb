# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
raw = pd.read_csv("../data/FR_hv_parties_678_raw.csv")
pd.set_option('display.max_columns', 500)

# %%
raw.head()
# Out:
#   cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 0    FR  ESS1-8e01       1.0  12.12.2018  155261  ESS6e02_4         6
# 1    FR  ESS1-8e01       1.0  12.12.2018  155262  ESS6e02_4         6
# 2    FR  ESS1-8e01       1.0  12.12.2018  155263  ESS6e02_4         6
# 3    FR  ESS1-8e01       1.0  12.12.2018  155264  ESS6e02_4         6
# 4    FR  ESS1-8e01       1.0  12.12.2018  155265  ESS6e02_4         6
#
#    edition  idno   dweight   pspwght   pweight  lrscale  prtvtcfr  ipcrtiv  \
# 0      2.4     4  1.098133  0.761439  2.702678        5        66        3
# 1      2.4     6  2.196265  1.545594  2.702678        8        10        5
# 2      2.4    10  1.098133  0.772797  2.702678        9        10        1
# 3      2.4    12  2.196265  1.356859  2.702678       10        10        1
# 4      2.4    13  1.098133  0.589189  2.702678       77        66        4
#
#    imprich  ipeqopt  ipshabt  impsafe  impdiff  ipfrule  ipudrst  ipmodst  \
# ...

# %%
raw.columns
# Out:
# Index(['cntry', 'cname', 'cedition', 'cproddat', 'cseqno', 'name', 'essround',
#        'edition', 'idno', 'dweight', 'pspwght', 'pweight', 'lrscale',
#        'prtvtcfr', 'ipcrtiv', 'imprich', 'ipeqopt', 'ipshabt', 'impsafe',
#        'impdiff', 'ipfrule', 'ipudrst', 'ipmodst', 'ipgdtim', 'impfree',
#        'iphlppl', 'ipsuces', 'ipstrgv', 'ipadvnt', 'ipbhprp', 'iprspot',
#        'iplylfr', 'impenv', 'imptrad', 'impfun'],
#       dtype='object')

# %%
raw_clean = raw.drop(columns=['cname', 
                              'cedition', 
                              'cproddat', 
                              'cseqno',
                              'name',
                              'edition',
                              'dweight', 
                              'pspwght', 
                              'pweight'])

# %%
raw_clean.head()
# Out:
#   cntry  essround  idno  lrscale  prtvtcfr  ipcrtiv  imprich  ipeqopt  \
# 0    FR         6     4        5        66        3        4        1
# 1    FR         6     6        8        10        5        4        1
# 2    FR         6    10        9        10        1        6        1
# 3    FR         6    12       10        10        1        1        1
# 4    FR         6    13       77        66        4        6        1
#
#    ipshabt  impsafe  impdiff  ipfrule  ipudrst  ipmodst  ipgdtim  impfree  \
# 0        2        4        4        5        3        4        4        2
# 1        1        1        1        1        1        1        1        4
# 2        6        1        5        1        1        1        1        6
# 3        1        1        4        1        1        1        1        1
# 4        6        1        1        1        1        1        2        4
#
#    iphlppl  ipsuces  ipstrgv  ipadvnt  ipbhprp  iprspot  iplylfr  impenv  \
# ...

# %%
cols = {'ipcrtiv':'new_ideas',
        'imprich':'rich',
        'ipeqopt':'equality',
        'ipshabt':'abilities',
        'impsafe':'safety',
        'impdiff':'new_diff',
        'ipfrule':'obey',
        'ipudrst':'understand_diff',
        'ipmodst':'modesty',
        'ipgdtim':'good_time',
        'impfree':'freedom',
        'iphlppl':'help_others',
        'ipsuces':'success',
        'ipstrgv':'strong_gov',
        'ipadvnt':'adventures',
        'ipbhprp':'behave',
        'iprspot':'get_respect',
        'iplylfr':'loyalty',
        'impenv':'nature',
        'imptrad':'traditions',
        'impfun':'fun_pleasure',
        'cntry':'country',
        'essround':'round',
        'lrscale':'leftright_scale',
        'prtvtcfr':'party'}

# %%
fr_hv = raw_clean.rename(columns=cols)

# %%
fr_hv["idno"].value_counts()
# Out:
# 4120    3
# 1369    3
# 2722    3
# 2718    3
# 2629    3
#        ..
# 198     1
# 4292    1
# 2235    1
# 4280    1
# 4098    1
# Name: idno, Length: 3625, dtype: int64

# %%
fr_hv[fr_hv["idno"]==4120]
# Out:
#      country  round  idno  leftright_scale  party  new_ideas  rich  equality  \
# 1938      FR      6  4120                9     66          2     5         1
# 3854      FR      7  4120                6      2          4     6         3
# 5897      FR      8  4120                6     66          1     3         2
#
#       abilities  safety  new_diff  obey  understand_diff  modesty  good_time  \
# 1938          3       2         2     4                2        2          2
# 3854          6       5         5     5                3        2          4
# 5897          1       1         1     2                1        2          1
#
#       freedom  help_others  success  strong_gov  adventures  behave  \
# 1938        4            2        4           3           6       2
# 3854        4            4        6           5           5       5
# 5897        1            2        1           1           2       3
#
#       get_respect  loyalty  nature  traditions  fun_pleasure
# ...

# %%
#Also in the case of FR, some ids were used repeatedly but this is not an issue now

# %%
fr_hv["party"].value_counts()
# Out:
# 66    2196
# 9     1147
# 10     966
# 2      377
# 77     243
# 12     189
# 6      145
# 88     141
# 11     134
# 15      95
# 7       58
# 8       49
# 13      48
# 1       42
# 5       38
# 14      37
# 4       26
# 16      15
# 3        9
# Name: party, dtype: int64

# %% [markdown]
# ### We divide our df in 3:
# ### fr_ext: those who voted for FN (party == 2)
# ### fr_novot: those who didn´t vote (party == 66)
# ### for_noext: the rest (also excluding those who didn´t answer(77) or didn´t know(88)

# %%
fr_ext = fr_hv[fr_hv["party"] == 2]

# %%
fr_novot = fr_hv[fr_hv["party"] == 66]

# %%
fr_noext = fr_hv[~fr_hv["party"].isin([2,77,88,66])]

# %%
fr_ext.describe()
# Out:
#             round         idno  leftright_scale  party   new_ideas  \
# count  377.000000   377.000000       377.000000  377.0  377.000000
# mean     6.997347  2095.156499         7.904509    2.0    2.583554
# std      0.817035  1276.715308        10.293636    0.0    1.366018
# min      6.000000     9.000000         0.000000    2.0    1.000000
# 25%      6.000000   924.000000         5.000000    2.0    1.000000
# 50%      7.000000  2042.000000         7.000000    2.0    2.000000
# 75%      8.000000  3228.000000         9.000000    2.0    3.000000
# max      8.000000  4297.000000        88.000000    2.0    8.000000
#
#              rich    equality   abilities      safety    new_diff        obey  \
# count  377.000000  377.000000  377.000000  377.000000  377.000000  377.000000
# mean     4.737401    2.342175    3.379310    2.485411    2.986737    3.925729
# std      1.201730    1.321729    1.475652    1.374318    1.455852    1.576017
# ...

# %%
fr_noext.describe()
# Out:
#              round         idno  leftright_scale        party    new_ideas  \
# count  2998.000000  2998.000000      2998.000000  2998.000000  2998.000000
# mean      6.934623  2090.411274         5.900600     9.527352     2.538359
# std       0.827293  1181.445595         9.401233     2.166975     1.307187
# min       6.000000     1.000000         0.000000     1.000000     1.000000
# 25%       6.000000  1093.250000         3.000000     9.000000     1.000000
# 50%       7.000000  2114.000000         5.000000     9.000000     2.000000
# 75%       8.000000  3095.500000         7.000000    10.000000     3.000000
# max       8.000000  4299.000000        88.000000    16.000000     8.000000
#
#               rich     equality    abilities       safety     new_diff  \
# count  2998.000000  2998.000000  2998.000000  2998.000000  2998.000000
# mean      4.939960     1.828219     3.701134     2.743496     3.092061
# std       1.009992     1.051324     1.452187     1.427803     1.441159
# ...

# %%
fr_novot.describe()
#Note: the leftright_scale mean is 13 because many people replied 88 (don´t know)
#The scale for left_right goes: 0--> left, 10--> right
# Out:
#              round         idno  leftright_scale   party    new_ideas  \
# count  2196.000000  2196.000000      2196.000000  2196.0  2196.000000
# mean      7.138434  2159.122040        13.385246    66.0     2.675319
# std       0.797466  1201.476307        24.765231     0.0     1.372609
# min       6.000000     1.000000         0.000000    66.0     1.000000
# 25%       6.000000  1127.000000         4.000000    66.0     2.000000
# 50%       7.000000  2167.000000         5.000000    66.0     2.000000
# 75%       8.000000  3188.500000         7.000000    66.0     4.000000
# max       8.000000  4300.000000        88.000000    66.0     8.000000
#
#               rich     equality    abilities       safety     new_diff  \
# count  2196.000000  2196.000000  2196.000000  2196.000000  2196.000000
# mean      4.755464     1.934426     3.382969     2.672131     2.959472
# std       1.224965     1.124698     1.528905     1.444798     1.466310
# ...
