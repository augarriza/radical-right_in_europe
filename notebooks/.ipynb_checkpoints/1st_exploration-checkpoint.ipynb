# %%
import pandas as pd

# %%
raw_df = pd.read_csv("../data/ESS1-8e01.csv", low_memory=False)

# %%
raw_df.head(5)
# Out:
#   cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 0    AT  ESS1-8e01       1.0  12.12.2018       1  ESS1e06_6         1
# 1    AT  ESS1-8e01       1.0  12.12.2018       2  ESS1e06_6         1
# 2    AT  ESS1-8e01       1.0  12.12.2018       3  ESS1e06_6         1
# 3    AT  ESS1-8e01       1.0  12.12.2018       4  ESS1e06_6         1
# 4    AT  ESS1-8e01       1.0  12.12.2018       5  ESS1e06_6         1
#
#    edition  idno  dweight  ...  dscroth  dscrdk  dscrref  dscrnap  dscrna  \
# 0      6.6     1   0.9452  ...        0       0        0        1       0
# 1      6.6     2   0.4726  ...        1       0        0        0       0
# 2      6.6     3   0.9452  ...        0       0        0        1       0
# 3      6.6     4   0.9452  ...        0       0        0        1       0
# 4      6.6     6   1.8905  ...        0       0        0        1       0
#
#    ctzship  facntr  fbrncnt  mocntr  mbrncnt
# 0       66       1      NaN       1      NaN
# ...

# %%
raw_df[raw_df["cntry"] == "ES"]
# Out:
#        cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 114463    ES  ESS1-8e01       1.0  12.12.2018  114464  ESS1e06_6         1
# 114464    ES  ESS1-8e01       1.0  12.12.2018  114465  ESS1e06_6         1
# 114465    ES  ESS1-8e01       1.0  12.12.2018  114466  ESS1e06_6         1
# 114466    ES  ESS1-8e01       1.0  12.12.2018  114467  ESS1e06_6         1
# 114467    ES  ESS1-8e01       1.0  12.12.2018  114468  ESS1e06_6         1
# ...      ...        ...       ...         ...     ...        ...       ...
# 129959    ES  ESS1-8e01       1.0  12.12.2018  129960  ESS8e02_1         8
# 129960    ES  ESS1-8e01       1.0  12.12.2018  129961  ESS8e02_1         8
# 129961    ES  ESS1-8e01       1.0  12.12.2018  129962  ESS8e02_1         8
# 129962    ES  ESS1-8e01       1.0  12.12.2018  129963  ESS8e02_1         8
# 129963    ES  ESS1-8e01       1.0  12.12.2018  129964  ESS8e02_1         8
#
# ...
