# %%
import pandas as pd

# %%
df = pd.read_csv("../data/DE_human_values.csv")
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#   cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 0    DE  ESS1-8e01       1.0  12.12.2018   84321  ESS7e02_2         7
# 1    DE  ESS1-8e01       1.0  12.12.2018   84322  ESS7e02_2         7
# 2    DE  ESS1-8e01       1.0  12.12.2018   84323  ESS7e02_2         7
# 3    DE  ESS1-8e01       1.0  12.12.2018   84324  ESS7e02_2         7
# 4    DE  ESS1-8e01       1.0  12.12.2018   84325  ESS7e02_2         7
#
#    edition      idno   dweight   pspwght   pweight  ipcrtiv  imprich  ipeqopt  \
# 0      2.2  10000011  0.531346  0.607555  2.304126      2.0      4.0      1.0
# 1      2.2  10000021  0.531346  0.462666  2.304126      2.0      5.0      2.0
# 2      2.2  10000051  1.227808  0.640290  2.304126      4.0      5.0      1.0
# 3      2.2  10000061  1.227808  1.142616  2.304126      2.0      6.0      2.0
# 4      2.2  10000111  1.227808  0.852731  2.304126      1.0      5.0      2.0
#
# ...

# %%
df.shape
# Out:
# (5897, 33)
